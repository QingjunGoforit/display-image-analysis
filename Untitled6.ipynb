# %%
import sys
sys.path.append('/Users/qingjunwang/Documents/code/python')
import main_check_focus_exp as main
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
import re
import io
import os

# %%
img_path='/Users/qingjunwang/Documents/image files/speckle 2 study/yuhang/raw MM SM/'+'EPIC_FL2_D2C2_YSSI_P20_SS_TD_Green_50mA_25degrees_X0.000_Y0.000_Z31.838_Exp123231.png'

# %%
image_save_path='/Users/qingjunwang/Documents/image files/speckle 2 study/yuhang/raw MM SM/'

# %%
main.normalize_max_255(img_path,'green',image_save_path)
# Out:
# scaled image saved
